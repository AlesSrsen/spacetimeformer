# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dcaed75c-80d8-493b-9701-d225bc7eade3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcaed75c-80d8-493b-9701-d225bc7eade3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# Read excel to pandas
xl = pd.ExcelFile(uploaded.get("eth_timeseries_hourly.xlsx"))
print(f"Sheet names: {xl.sheet_names}")
df = xl.parse(xl.sheet_names[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-4c7cdf5d69ba> in <cell line: 3>()
#       1 import pandas as pd
#       2 # Read excel to pandas
# ----> 3 xl = pd.ExcelFile(uploaded.get("eth_timeseries_hourly.xlsx"))
#       4 print(f"Sheet names: {xl.sheet_names}")
#       5 df = xl.parse(xl.sheet_names[0])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
# ...

# %%
df.head()
# Out:
#   asset_id,timestamp,time,open,close,high,low,volume,volume_24h,market_cap,circulating_supply,url_shares,unique_url_shares,reddit_posts,reddit_posts_score,reddit_comments,reddit_comments_score,tweets,tweet_spam,tweet_followers,tweet_quotes,tweet_retweets,tweet_replies,tweet_favorites,tweet_score,tweet_sentiment1,tweet_sentiment2,tweet_sentiment3,tweet_sentiment4,tweet_sentiment5,tweet_sentiment_impact1,tweet_sentiment_impact2,tweet_sentiment_impact3,tweet_sentiment_impact4,tweet_sentiment_impact5,social_score,average_sentiment,sentiment_absolute,sentiment_relative,search_average,news,price_score,social_impact_score,correlation_rank,galaxy_score,volatility,alt_rank,alt_rank_30d,market_cap_rank,percent_change_24h_rank,volume_24h_rank,social_volume_24h_rank,social_score_24h_rank,medium,youtube,social_contributors,influential_content,influential_content_score,social_volume,social_volume_global,social_dominance,market_cap_global,market_dominance,social_volume_calc_24h,social_score_calc_24
# ...

# %%
# Print the first row
print(f"First row (feature names): {df.iloc[0]}")
print(f"Names: {df.Name}")
filtered_df = df[df['Name'].isin(["blubb", "nala"])]

# %% [markdown]
# # Use CSV instead

# %%
from google.colab import files
import pandas as pd

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a9ddea9-fd9e-4090-b985-fde54f8be2d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a9ddea9-fd9e-4090-b985-fde54f8be2d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read csv to pandas
# Load the uploaded CSV file as a DataFrame
from io import StringIO
uploaded_file = uploaded["eth_timeseries_hourly.csv"]  # Access the file from the uploaded dictionary
df = pd.read_csv(StringIO(uploaded_file.decode("utf-8")))  # Decode bytes to string and read into DataFram
df.head()
# Out:
#    asset_id   timestamp                 time    open   close    high     low  \
# 0         2  1567036800  2019-08-29 00:00:00  173.13  168.95  173.17  164.19
# 1         2  1567123200  2019-08-30 00:00:00  167.61  168.52  170.47  165.95
# 2         2  1567209600  2019-08-31 00:00:00  168.92  172.15  174.99  166.29
# 3         2  1567296000  2019-09-01 00:00:00  172.97  171.42  173.88  168.24
# 4         2  1567382400  2019-09-02 00:00:00  171.45  178.76  181.47  170.77
#
#    volume  volume_24h    market_cap  ...  social_contributors  \
# 0     NaN         NaN  1.823020e+10  ...                  NaN
# 1     NaN         NaN  1.820780e+10  ...                  NaN
# 2     NaN         NaN  1.856412e+10  ...                  NaN
# 3     NaN         NaN  1.849572e+10  ...                  NaN
# 4     NaN         NaN  1.919514e+10  ...                  NaN
#
#    influential_content  influential_content_score  social_volume  \
# ...

# %%
# prompt: Drop all columns apart from: "asset_id", "timestamp", "time"

columns_to_keep = ["asset_id", "timestamp", "time", "open", "close", "high", "low", "volume", "volume_24h", "market_cap", "circulating_supply", "volatility"]

df = df[columns_to_keep]
print(df.head())
# Out:
#    asset_id   timestamp                 time    open   close    high     low  \
# 0         2  1567036800  2019-08-29 00:00:00  173.13  168.95  173.17  164.19
# 1         2  1567123200  2019-08-30 00:00:00  167.61  168.52  170.47  165.95
# 2         2  1567209600  2019-08-31 00:00:00  168.92  172.15  174.99  166.29
# 3         2  1567296000  2019-09-01 00:00:00  172.97  171.42  173.88  168.24
# 4         2  1567382400  2019-09-02 00:00:00  171.45  178.76  181.47  170.77
#
#    volume  volume_24h    market_cap  circulating_supply  volatility
# 0     NaN         NaN  1.823020e+10                 NaN    0.957914
# 1     NaN         NaN  1.820780e+10                 NaN    0.745629
# 2     NaN         NaN  1.856412e+10                 NaN    0.130370
# 3     NaN         NaN  1.849572e+10                 NaN    0.240138
# 4     NaN         NaN  1.919514e+10                 NaN    0.263261

# %%
# prompt: for every column print the NaN value count

print(df.shape)

for col in df.columns:
  print(f"Column '{col}' has {df[col].isna().sum()} NaN values.")
# Out:
# (38656, 12)
# Column 'asset_id' has 0 NaN values.
# Column 'timestamp' has 0 NaN values.
# Column 'time' has 0 NaN values.
# Column 'open' has 57 NaN values.
# Column 'close' has 0 NaN values.
# Column 'high' has 57 NaN values.
# Column 'low' has 57 NaN values.
# Column 'volume' has 8689 NaN values.
# Column 'volume_24h' has 8515 NaN values.
# Column 'market_cap' has 55 NaN values.
# Column 'circulating_supply' has 8248 NaN values.
# Column 'volatility' has 98 NaN values.

# %%
# Export to CSV
df.to_csv('exported_data_12_cols.csv', index=False)  # index=False prevents row indices from being written

# Download the CSV file
files.download('exported_data_12_cols.csv')

# %%
# prompt: only keep the first 500 rows

df_500 = df.head(500)
df_500.to_csv('preprocessed_12_cols_500_rows_eth_timeseries.csv', index=False)  # index=False prevents row indices from being written

# Download the CSV file
files.download('preprocessed_12_cols_500_rows_eth_timeseries.csv')

# %% [markdown]
# Upload of the preprocessed CSV

# %%
pre_uploaded = files.upload()
# Out:
#      <input type="file" id="files-87186a8c-8f0c-4509-ae41-8b7f071ae71f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87186a8c-8f0c-4509-ae41-8b7f071ae71f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from io import StringIO
uploaded_file = pre_uploaded["preprocessed_eth_timeseries_hourly.csv"]  # Access the file from the uploaded dictionary
df = pd.read_csv(StringIO(uploaded_file.decode("utf-8")))  # Decode bytes to string and read into DataFram
df.head(20)
# Out:
#     asset_id   timestamp                 time        high         low  \
# 0          2  1567036800  2019-08-29 00:00:00  173.170000  164.190000
# 1          2  1567123200  2019-08-30 00:00:00  170.470000  165.950000
# 2          2  1567209600  2019-08-31 00:00:00  174.990000  166.290000
# 3          2  1567296000  2019-09-01 00:00:00  173.880000  168.240000
# 4          2  1567382400  2019-09-02 00:00:00  181.470000  170.770000
# 5          2  1567468800  2019-09-03 00:00:00  182.930000  174.830000
# 6          2  1567555200  2019-09-04 00:00:00  180.460000  174.060000
# 7          2  1567641600  2019-09-05 00:00:00  175.860000  170.070000
# 8          2  1567728000  2019-09-06 00:00:00  178.380000  165.670000
# 9          2  1567814400  2019-09-07 00:00:00  181.090000  168.700000
# 10         2  1567900800  2019-09-08 00:00:00  184.530000  177.030000
# 11         2  1567954800  2019-09-08 15:00:00  182.546495  180.257378
# ...

# %%
print(f"{df['volume'].isna().sum()} values are NaN from {df.shape[0]}")
# Out:
# 8689 values are NaN from 38656

# %%
print(f"{df['volume'].mean()} is the mean of the volume column")
# Out:
# 342363420952.87317 is the mean of the volume column

# %%
print(f"{df['volume'].describe()}")
# Out:
# count    2.996700e+04
# mean     3.423634e+11
# std      4.178663e+13
# min      9.883325e+07
# 25%      4.292709e+08
# 50%      7.508369e+08
# 75%      1.245638e+09
# max      5.142100e+15
# Name: volume, dtype: float64

# %%
mean_value = df['volume'].mean()
print(mean_value)
# Out:
# 342363420952.87317

# %%
print(df['volume'].min())  # Minimum value
print(df['volume'].max())  # Maximum value
df['volume'].hist()  # Plot histogram (if numeric)
# Out:
# 98833250.0
# 5142100136294968.0
# <Axes: >

# %% [markdown]
# Preprocessing Debug Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from io import StringIO
df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/DataminingAndTimeSeries/preprocessed_12_cols_500_rows_eth_timeseries.csv")  # Decode bytes to string and read into DataFram
df.head()
# Out:
#    asset_id   timestamp              time    open   close    high     low  \
# 0         2  1567036800  2019-08-29 00:00  173.13  168.95  173.17  164.19
# 1         2  1567123200  2019-08-30 00:00  167.61  168.52  170.47  165.95
# 2         2  1567209600  2019-08-31 00:00  168.92  172.15  174.99  166.29
# 3         2  1567296000  2019-09-01 00:00  172.97  171.42  173.88  168.24
# 4         2  1567382400  2019-09-02 00:00  171.45  178.76  181.47  170.77
#
#    volume  volume_24h    market_cap  circulating_supply  volatility
# 0     NaN         NaN  1.823020e+10                 NaN    0.957914
# 1     NaN         NaN  1.820780e+10                 NaN    0.745629
# 2     NaN         NaN  1.856412e+10                 NaN    0.130370
# 3     NaN         NaN  1.849572e+10                 NaN    0.240138
# 4     NaN         NaN  1.919514e+10                 NaN    0.263261

# %%
from datetime import datetime
df['time'] = pd.to_datetime(df['time']).dt.strftime("%Y-%m-%d %H:%M")
df.head()
# Out:
#    asset_id   timestamp              time    open   close    high     low  \
# 0         2  1567036800  2019-08-29 00:00  173.13  168.95  173.17  164.19
# 1         2  1567123200  2019-08-30 00:00  167.61  168.52  170.47  165.95
# 2         2  1567209600  2019-08-31 00:00  168.92  172.15  174.99  166.29
# 3         2  1567296000  2019-09-01 00:00  172.97  171.42  173.88  168.24
# 4         2  1567382400  2019-09-02 00:00  171.45  178.76  181.47  170.77
#
#    volume  volume_24h    market_cap  circulating_supply  volatility
# 0     NaN         NaN  1.823020e+10                 NaN    0.957914
# 1     NaN         NaN  1.820780e+10                 NaN    0.745629
# 2     NaN         NaN  1.856412e+10                 NaN    0.130370
# 3     NaN         NaN  1.849572e+10                 NaN    0.240138
# 4     NaN         NaN  1.919514e+10                 NaN    0.263261

# %%
import numpy as np
df = df.replace(np.nan, 2)
df.head()
# Out:
#    asset_id   timestamp              time    open   close    high     low  \
# 0         2  1567036800  2019-08-29 00:00  173.13  168.95  173.17  164.19
# 1         2  1567123200  2019-08-30 00:00  167.61  168.52  170.47  165.95
# 2         2  1567209600  2019-08-31 00:00  168.92  172.15  174.99  166.29
# 3         2  1567296000  2019-09-01 00:00  172.97  171.42  173.88  168.24
# 4         2  1567382400  2019-09-02 00:00  171.45  178.76  181.47  170.77
#
#    volume  volume_24h    market_cap  circulating_supply  volatility
# 0     2.0         2.0  1.823020e+10                 2.0    0.957914
# 1     2.0         2.0  1.820780e+10                 2.0    0.745629
# 2     2.0         2.0  1.856412e+10                 2.0    0.130370
# 3     2.0         2.0  1.849572e+10                 2.0    0.240138
# 4     2.0         2.0  1.919514e+10                 2.0    0.263261

# %%
df.to_csv('/content/drive/MyDrive/ColabNotebooks/DataminingAndTimeSeries/preprocessed_12_cols_500_rows_noNaN_eth_timeseries.csv', index=False)  # index=False prevents row indices from being written

# Download the CSV file
#files.download('preprocessed_12_cols_500_rows_noNaN_eth_timeseries.csv')
